# %%
import os, sys
sys.path.append(os.path.join('..', 'src'))

# %%
conda activate tf_gpu
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from chess_zero.agent.player_chess import ChessPlayer
from chess_zero.config import Config, PlayWithHumanConfig
from chess_zero.env.chess_env import ChessEnv

# %%
def get_player(config):
    from chess_zero.agent.model_chess import ChessModel
    from chess_zero.lib.model_helper import load_best_model_weight
    model = ChessModel(config)
    if not load_best_model_weight(model):
        raise RuntimeError("Best model not found!")
    return ChessPlayer(config, model.get_pipes(config.play.search_threads))

def info(depth, move, score):
    print(f"info score cp {int(score*100)} depth {depth} pv {move}")
    sys.stdout.flush()

# %%
default_config = Config()
PlayWithHumanConfig().update_play_config(default_config.play)
me_player = None
env = ChessEnv().reset()

# %%
env.board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# bestmove g1f3

# %%
env.step(action)
env.board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/5N2/PPPPPPPP/RNBQKB1R b KQkq - 1 1')

# %%
env.step('b8c6')
env.board
# Out:
# Board('r1bqkbnr/pppppppp/2n5/8/8/5N2/PPPPPPPP/RNBQKB1R w KQkq - 2 2')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove d2d4
# Board('r1bqkbnr/pppppppp/2n5/8/3P4/5N2/PPP1PPPP/RNBQKB1R b KQkq - 0 2')

# %%
env.step('c6d4')
env.board
# Out:
# Board('r1bqkbnr/pppppppp/8/8/3n4/5N2/PPP1PPPP/RNBQKB1R w KQkq - 0 3')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove f3d4
# Board('r1bqkbnr/pppppppp/8/8/3N4/8/PPP1PPPP/RNBQKB1R b KQkq - 0 3')

# %%
env.step('c7c5')
env.board
# Out:
# Board('r1bqkbnr/pp1ppppp/8/2p5/3N4/8/PPP1PPPP/RNBQKB1R w KQkq - 0 4')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove d4b3
# Board('r1bqkbnr/pp1ppppp/8/2p5/8/1N6/PPP1PPPP/RNBQKB1R b KQkq - 1 4')

# %%
env.step('c5c4')
env.board
# Out:
# Board('r1bqkbnr/pp1ppppp/8/8/2p5/1N6/PPP1PPPP/RNBQKB1R w KQkq - 0 5')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove b3d4
# Board('r1bqkbnr/pp1ppppp/8/8/2pN4/8/PPP1PPPP/RNBQKB1R b KQkq - 1 5')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove b1c3
# Board('r1bqkbnr/pp1p1ppp/4p3/8/2pN4/2N5/PPP1PPPP/R1BQKB1R b KQkq - 1 6')

# %%
env.step('f8b4')
env.board
# Out:
# Board('r1bqk1nr/pp1p1ppp/4p3/8/1bpN4/2N5/PPP1PPPP/R1BQKB1R w KQkq - 2 7')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove c1d2
# Board('r1bqk1nr/pp1p1ppp/4p3/8/1bpN4/2N5/PPPBPPPP/R2QKB1R b KQkq - 3 7')

# %%
env.step('e6e5')
env.board
# Out:
# Board('r1bqk1nr/pp1p1ppp/8/4p3/1bpN4/2N5/PPPBPPPP/R2QKB1R w KQkq - 0 8')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove d4f3
# Board('r1bqk1nr/pp1p1ppp/8/4p3/1bp5/2N2N2/PPPBPPPP/R2QKB1R b KQkq - 1 8')

# %%
env.step('g8f6')
env.board
# Out:
# Board('r1bqk2r/pp1p1ppp/5n2/4p3/1bp5/2N2N2/PPPBPPPP/R2QKB1R w KQkq - 2 9')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove e2e3
# Board('r1bqk2r/pp1p1ppp/5n2/4p3/1bp5/2N1PN2/PPPB1PPP/R2QKB1R b KQkq - 0 9')

# %%
env.step('d8b6')
env.board
# Out:
# Board('r1b1k2r/pp1p1ppp/1q3n2/4p3/1bp5/2N1PN2/PPPB1PPP/R2QKB1R w KQkq - 1 10')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove f3e5
# Board('r1b1k2r/pp1p1ppp/1q3n2/4N3/1bp5/2N1P3/PPPB1PPP/R2QKB1R b KQkq - 0 10')

# %%
env.step('b6e6')
env.board
# Out:
# Board('r1b1k2r/pp1p1ppp/4qn2/4N3/1bp5/2N1P3/PPPB1PPP/R2QKB1R w KQkq - 1 11')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove e5f3
# Board('r1b1k2r/pp1p1ppp/4qn2/8/1bp5/2N1PN2/PPPB1PPP/R2QKB1R b KQkq - 2 11')

# %%
env.step('h7h5')
env.board
# Out:
# Board('r1b1k2r/pp1p1pp1/4qn2/7p/1bp5/2N1PN2/PPPB1PPP/R2QKB1R w KQkq - 0 12')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove f3d4
# Board('r1b1k2r/pp1p1pp1/4qn2/7p/1bpN4/2N1P3/PPPB1PPP/R2QKB1R b KQkq - 1 12')

# %%
env.step('e6d6')
env.board
# Out:
# Board('r1b1k2r/pp1p1pp1/3q1n2/7p/1bpN4/2N1P3/PPPB1PPP/R2QKB1R w KQkq - 2 13')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove c3b5
# Board('r1b1k2r/pp1p1pp1/3q1n2/1N5p/1bpN4/4P3/PPPB1PPP/R2QKB1R b KQkq - 3 13')

# %%
env.step('d6c5')
env.board
# Out:
# Board('r1b1k2r/pp1p1pp1/5n2/1Nq4p/1bpN4/4P3/PPPB1PPP/R2QKB1R w KQkq - 4 14')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove c2c3
# Board('r1b1k2r/pp1p1pp1/5n2/1Nq4p/1bpN4/2P1P3/PP1B1PPP/R2QKB1R b KQkq - 0 14')

# %%
env.step('h8h6')
env.board
# Out:
# Board('r1b1k3/pp1p1pp1/5n1r/1Nq4p/1bpN4/2P1P3/PP1B1PPP/R2QKB1R w KQq - 1 15')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove c3b4
# Board('r1b1k3/pp1p1pp1/5n1r/1Nq4p/1PpN4/4P3/PP1B1PPP/R2QKB1R b KQq - 0 15')

# %%
env.step('c5g5')
env.board
# Out:
# Board('r1b1k3/pp1p1pp1/5n1r/1N4qp/1PpN4/4P3/PP1B1PPP/R2QKB1R w KQq - 1 16')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove b5c7
# Board('r1b1k3/ppNp1pp1/5n1r/6qp/1PpN4/4P3/PP1B1PPP/R2QKB1R b KQq - 2 16')

# %%
env.step('e8d8')
env.board
# Out:
# Board('r1bk4/ppNp1pp1/5n1r/6qp/1PpN4/4P3/PP1B1PPP/R2QKB1R w KQ - 3 17')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove c7a8
# Board('N1bk4/pp1p1pp1/5n1r/6qp/1PpN4/4P3/PP1B1PPP/R2QKB1R b KQ - 0 17')

# %%
env.step('g5e5')
env.board
# Out:
# Board('N1bk4/pp1p1pp1/5n1r/4q2p/1PpN4/4P3/PP1B1PPP/R2QKB1R w KQ - 1 18')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove f1c4
# Board('N1bk4/pp1p1pp1/5n1r/4q2p/1PBN4/4P3/PP1B1PPP/R2QK2R b KQ - 0 18')

# %%
env.step('b7b5')
env.board
# Out:
# Board('N1bk4/p2p1pp1/5n1r/1p2q2p/1PBN4/4P3/PP1B1PPP/R2QK2R w KQ - 0 19')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove c4b3
# Board('N1bk4/p2p1pp1/5n1r/1p2q2p/1P1N4/1B2P3/PP1B1PPP/R2QK2R b KQ - 1 19')

# %%
env.step('e5b8')
env.board
# Out:
# Board('Nqbk4/p2p1pp1/5n1r/1p5p/1P1N4/1B2P3/PP1B1PPP/R2QK2R w KQ - 2 20')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove a2a4
# Board('Nqbk4/p2p1pp1/5n1r/1p5p/PP1N4/1B2P3/1P1B1PPP/R2QK2R b KQ - 0 20')

# %%
env.step('b8a8')
env.board
# Out:
# Board('q1bk4/p2p1pp1/5n1r/1p5p/PP1N4/1B2P3/1P1B1PPP/R2QK2R w KQ - 0 21')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove b3f7
# Board('q1bk4/p2p1Bp1/5n1r/1p5p/PP1N4/4P3/1P1B1PPP/R2QK2R b KQ - 0 21')

# %%
env.step('b5a4')
env.board
# Out:
# Board('q1bk4/p2p1Bp1/5n1r/7p/pP1N4/4P3/1P1B1PPP/R2QK2R w KQ - 0 22')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove d1a4
# Board('q1bk4/p2p1Bp1/5n1r/7p/QP1N4/4P3/1P1B1PPP/R3K2R b KQ - 0 22')

# %%
env.step('c8b7')
env.board
# Out:
# Board('q2k4/pb1p1Bp1/5n1r/7p/QP1N4/4P3/1P1B1PPP/R3K2R w KQ - 1 23')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove f2f3
# Board('q2k4/pb1p1Bp1/5n1r/7p/QP1N4/4PP2/1P1B2PP/R3K2R b KQ - 0 23')

# %%
env.step('h6h8')
env.board
# Out:
# Board('q2k3r/pb1p1Bp1/5n2/7p/QP1N4/4PP2/1P1B2PP/R3K2R w KQ - 1 24')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove e1g1
# Board('q2k3r/pb1p1Bp1/5n2/7p/QP1N4/4PP2/1P1B2PP/R4RK1 b - - 2 24')

# %%
env.step('h8f8')
env.board
# Out:
# Board('q2k1r2/pb1p1Bp1/5n2/7p/QP1N4/4PP2/1P1B2PP/R4RK1 w - - 3 25')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove f7g6
# Board('q2k1r2/pb1p2p1/5nB1/7p/QP1N4/4PP2/1P1B2PP/R4RK1 b - - 4 25')

# %%
env.step('f6d5')
env.board
# Out:
# Board('q2k1r2/pb1p2p1/6B1/3n3p/QP1N4/4PP2/1P1B2PP/R4RK1 w - - 5 26')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove a4a5
# Board('q2k1r2/pb1p2p1/6B1/Q2n3p/1P1N4/4PP2/1P1B2PP/R4RK1 b - - 6 26')

# %%
env.step('d8c8')
env.board
# Out:
# Board('q1k2r2/pb1p2p1/6B1/Q2n3p/1P1N4/4PP2/1P1B2PP/R4RK1 w - - 7 27')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove e3e4
# Board('q1k2r2/pb1p2p1/6B1/Q2n3p/1P1NP3/5P2/1P1B2PP/R4RK1 b - - 0 27')

# %%
env.step('d5e7')
env.board
# Out:
# Board('q1k2r2/pb1pn1p1/6B1/Q6p/1P1NP3/5P2/1P1B2PP/R4RK1 w - - 1 28')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove g6h5
# Board('q1k2r2/pb1pn1p1/8/Q6B/1P1NP3/5P2/1P1B2PP/R4RK1 b - - 0 28')

# %%
env.step('e7c6')
env.board
# Out:
# Board('q1k2r2/pb1p2p1/2n5/Q6B/1P1NP3/5P2/1P1B2PP/R4RK1 w - - 1 29')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove d4c6
# Board('q1k2r2/pb1p2p1/2N5/Q6B/1P2P3/5P2/1P1B2PP/R4RK1 b - - 0 29')

# %%
env.step('b7c6')
env.board
# Out:
# Board('q1k2r2/p2p2p1/2b5/Q6B/1P2P3/5P2/1P1B2PP/R4RK1 w - - 0 30')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove b4b5
# Board('q1k2r2/p2p2p1/2b5/QP5B/4P3/5P2/1P1B2PP/R4RK1 b - - 0 30')

# %%
env.step('c6d5')
env.board
# Out:
# Board('q1k2r2/p2p2p1/8/QP1b3B/4P3/5P2/1P1B2PP/R4RK1 w - - 1 31')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove a5a6
# Board('q1k2r2/p2p2p1/Q7/1P1b3B/4P3/5P2/1P1B2PP/R4RK1 b - - 2 31')

# %%
env.step('a8b7')
env.board
# Out:
# Board('2k2r2/pq1p2p1/Q7/1P1b3B/4P3/5P2/1P1B2PP/R4RK1 w - - 3 32')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove a6b7
# Board('2k2r2/pQ1p2p1/8/1P1b3B/4P3/5P2/1P1B2PP/R4RK1 b - - 0 32')

# %%
env.step('d5b7')
env.board
# Out:
# Board('2k2r2/pb1p2p1/8/1P5B/4P3/5P2/1P1B2PP/R4RK1 w - - 0 33')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove a1a7
# Board('2k2r2/Rb1p2p1/8/1P5B/4P3/5P2/1P1B2PP/5RK1 b - - 0 33')

# %%
env.step('f8f6')
env.board
# Out:
# Board('2k5/Rb1p2p1/5r2/1P5B/4P3/5P2/1P1B2PP/5RK1 w - - 1 34')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove f1a1
# Board('2k5/Rb1p2p1/5r2/1P5B/4P3/5P2/1P1B2PP/R5K1 b - - 2 34')

# %%
env.step('d7d5')
env.board
# Out:
# Board('2k5/Rb4p1/5r2/1P1p3B/4P3/5P2/1P1B2PP/R5K1 w - - 0 35')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove e4e5
# Board('2k5/Rb4p1/5r2/1P1pP2B/8/5P2/1P1B2PP/R5K1 b - - 0 35')

# %%
env.step('f6h6')
env.board
# Out:
# Board('2k5/Rb4p1/7r/1P1pP2B/8/5P2/1P1B2PP/R5K1 w - - 1 36')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove h5g4
# Board('2k5/Rb4p1/7r/1P1pP3/6B1/5P2/1P1B2PP/R5K1 b - - 2 36')

# %%
env.step('c8b8')
env.board
# Out:
# Board('1k6/Rb4p1/7r/1P1pP3/6B1/5P2/1P1B2PP/R5K1 w - - 3 37')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove b5b6
# Board('1k6/Rb4p1/1P5r/3pP3/6B1/5P2/1P1B2PP/R5K1 b - - 0 37')

# %%
env.step('h6b6')
env.board
# Out:
# Board('1k6/Rb4p1/1r6/3pP3/6B1/5P2/1P1B2PP/R5K1 w - - 0 38')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove d2f4
# Board('1k6/Rb4p1/1r6/3pP3/5BB1/5P2/1P4PP/R5K1 b - - 1 38')

# %%
env.step('b6b4')
env.board
# Out:
# Board('1k6/Rb4p1/8/3pP3/1r3BB1/5P2/1P4PP/R5K1 w - - 2 39')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove e5e6
# Board('1k6/Rb4p1/4P3/3p4/1r3BB1/5P2/1P4PP/R5K1 b - - 0 39')

# %%
env.step('b4f4')
env.board
# Out:
# Board('1k6/Rb4p1/4P3/3p4/5rB1/5P2/1P4PP/R5K1 w - - 0 40')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove e6e7
# Board('1k6/Rb2P1p1/8/3p4/5rB1/5P2/1P4PP/R5K1 b - - 0 40')

# %%
env.step('b7c6')
env.board
# Out:
# Board('1k6/R3P1p1/2b5/3p4/5rB1/5P2/1P4PP/R5K1 w - - 1 41')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove a7d7
# Board('1k6/3RP1p1/2b5/3p4/5rB1/5P2/1P4PP/R5K1 b - - 2 41')

# %%
env.step('f4a4')
env.board
# Out:
# Board('1k6/3RP1p1/2b5/3p4/r5B1/5P2/1P4PP/R5K1 w - - 3 42')

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board
# Out:
# bestmove e7e8q
# Board('1k2Q3/3R2p1/2b5/3p4/r5B1/5P2/1P4PP/R5K1 b - - 0 42')

# %%
env.step('c6a8')
env.board
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-3024fc571ca7> in <module>
# ----> 1 env.step('c6a8')
#       2 env.board
#
# C:\Users\G KALYAN\Downloads\deep-move-master\src\chess_zero\env\chess_env.py in step(self, action, check_over)
#      89             return
#      90
# ---> 91         self.board.push_uci(action)
#      92
#      93         self.num_halfmoves += 1
#
# C:\Anaconda3\envs\tf_gpu\lib\site-packages\chess\__init__.py in push_uci(self, uci)
#    2831             current position (but not a null move).
#    2832         """
# -> 2833         move = self.parse_uci(uci)
#    2834         self.push(move)
#    2835         return move
#
# C:\Anaconda3\envs\tf_gpu\lib\site-packages\chess\__init__.py in parse_uci(self, uci)
#    2818
#    2819         if not self.is_legal(move):
# -> 2820             raise ValueError("illegal uci: {!r} in {}".format(uci, self.fen()))
#    2821
#    2822         return move
#
# ValueError: illegal uci: 'c6a8' in 1k2Q3/3R2p1/2b5/3p4/r5B1/5P2/1P4PP/R5K1 b - - 0 42

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board

# %%
env.step('')
env.board

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board

# %%
env.step('')
env.board

# %%
if not me_player:
    me_player = get_player(default_config)
action = me_player.action(env, False)
print(f"bestmove {action}")
env.step(action)
env.board

# %%
env.step('')
env.board
